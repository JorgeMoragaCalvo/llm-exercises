# %%
from dotenv import load_dotenv
load_dotenv('.env')
# Out:
# True

# %%
from langchain_community.document_loaders import WebBaseLoader

urls = ['https://economictimes.indiatimes.com/market/stocks/news',
        'https://www.livemint.com/latest-news',
        'https://www.livemint.com/latest-news/page-2',
        'https://www.livemint.com/latest-news/page-3']
# Out:
# USER_AGENT environment variable not set, consider setting it to identify your requests.

# %%
loader = WebBaseLoader(web_paths=urls)

# %%
docs = []

async for doc in loader.alazy_load():
    docs.append(doc)
# Out:
# c:\Users\Jorge Moraga Calvo\Desktop\Python\langchain\.venv\Lib\site-packages\langchain_community\document_loaders\web_base.py:299: UserWarning: For better logging of progress, `pip install tqdm`
#   warnings.warn("For better logging of progress, `pip install tqdm`")

# %%
def format_docs(docs):
    return "\n\n".join([x.page_content for x in docs])

context = format_docs(docs)

# %%
import re

def text_clean(text):
    text = re.sub(r'\n\n+', '\n', text)
    text = re.sub(r'\t+', '\n', text)
    text = re.sub(r'\s+', ' ', text)
    return text

# %%
context = text_clean(context)

# %%
print(context)
# Out:
#  Most Viewed Business News Articles, Top News Articles | The Economic TimesBenchmarks Nifty23,045.25-26.55FEATURED FUNDS★★★★★HSBC Large Cap Fund Direct-Growth5Y Return15.13 % Invest NowFEATURED FUNDS★★★★★Canara Robeco ELSS Tax Saver Regular - Growth5Y Return16.97 % Invest NowEnglish EditionEnglish Editionहिन्दीગુજરાતીमराठीবাংলাಕನ್ನಡമലയാളംதமிழ்తెలుగు | 12 February, 2025, 09:27 PM IST | Today's ePaper My Watchlist SubscribeSign InHomeBUDGET'25ETPrimeMarketsMarket DataNewsIndustryRisePoliticsWealthMFTechCareersOpinionNRIPanacheVideosMore MenuYou are here: ET Home» 404 page404 page404 ERRORYou can search EconomicTimes.com for similar content, browse our most read articles, or go to our Home PageLatest NewsMost ReadMost SharedMost CommentedNewslettersMost Viewed Business NewsLast updated on 12 Feb,2025 09:27 PM Refresh'We don’t know. Vacate the premises': Infosys faces backlash for reportedly denying a crying female employee's plea to stay overnight10 Feb, 2025 04:19 PM ISTInfosys fired over 300 employees at its Mysuru campus after they failed internal evaluations. The trainees were asked to vacate the campus the same day despite their pleas to stay the night. Many of the terminated employees had waited over two years after receiving their offer letters before joining the company, only to be let go within months.Why stock market fell today: Investors lose Rs 9 lakh crore as Sensex crashes over 1,000 points; key factors that fueled the crash11 Feb, 2025 01:29 PM ISTStock market crash today: Indian equity indices fell for the fifth day, driven down by banking, auto, metal, and IT stocks. Contributing factors include U.S. trade policy, weak earnings, and foreign investor selling. President Trump's tariff hike on steel and aluminum, nervousness ahead of Fed Chair Powell’s testimony, and high U.S. bond yields added to the market's decline.Don't want to put foot in my mouth again but SIP or lump sum, investing in a costly asset class won't get you value: S Naren11 Feb, 2025 12:26 PM ISTS Naren, CIO at ICICI Prudential AMC, advises focusing on bank fixed deposits, debt mutual funds, and office spaces due to their underperformance over the past five years. He emphasizes the importance of investing in undervalued asset classes and maintaining a strategic asset allocation, especially in a market where valuations are high.BeerBiceps' Ranveer Allahbadia requests makers of Samay Raina's India’s Got Latent to do this after big controversy11 Feb, 2025 09:31 AM ISTYouTuber Ranveer Allahbadia has apologized for his offensive comment on Samay Raina's YouTube show. He admitted his remark was inappropriate and not funny. Allahbadia took full responsibility, emphasizing his intent to use his platform better. He asked for forgiveness and requested the show's makers to remove the insensitive sections from the video.Market falls over 10%: 25 years of history says it’s normal, but what’s next for investors?11 Feb, 2025 04:26 PM IST Stock Market crash: Stock market volatility has triggered sharp corrections, with Nifty50 falling over 12% from its peak. Small and midcaps are under pressure, while expert Jyotivardhan Jaipuria highlights the historical normalcy of market corrections and the need for stability.INFOCUS ON ET TODAYTOP STORIESTrump's Inauguration Day: What to expectDonald Trump's second term as US President will begin with his inauguration on Monday. He plans to sign numerous executive orders and hold a campaign-style rally. Several foreign leaders are invited, and outgoing President Joe Biden will attend. The events are largely funded by Trump's inauguration committee.Shocking discovery: New study finds extra Y chromosome in humans and it's not a good news for some menCommon diabetic drug Metformin may become a wonder drug to keep people young; Study finds promising results in monkeysTirupati Laddu Adulterated Ghee Controversy: How to identify purity of Ghee at homeToo much sitting can be fatal: Study of 45,000 people reveals the workout you need ...
